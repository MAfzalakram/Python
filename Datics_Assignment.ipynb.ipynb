# %%
user1 = input("Enter the name of user 1:")
user2 = input("Enter the name of user 2:")
word1 = "true"
word2 = "love"
t_frq = user1.count('t') + user2.count('t')
r_frq = user1.count('r') + user2.count('r')
u_frq = user1.count('u') + user2.count('u')
e_frq = user1.count('e') + user2.count('e')

l_frq = user1.count('l') + user2.count('l')
o_frq = user1.count('o') + user2.count('o')
v_frq = user1.count('v') + user2.count('v')
e_frq = user1.count('e') + user2.count('e')

true = t_frq + r_frq + u_frq + e_frq
love = l_frq + o_frq + v_frq + e_frq
love_score = str(true) + str(love)
print(f"love score = {love_score}")
# Out:
# Enter the name of user 1:rabia
# Enter the name of user 2:laraib
# love score = 21

# %%
fruits = ["apple", "orange", "tomato", "banana"]
for fruit in fruits:
    print(f" {fruit} has index = {fruits.index(fruit)}")
# Out:
#  apple has index = 0
#  orange has index = 1
#  tomato has index = 2
#  banana has index = 3
